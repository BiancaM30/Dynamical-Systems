# %%
#1 a)
reset()
t=var('t')
x=function('x')(t)

# %%
s=var('s')
f=function('f')(s)
f(s)=s*s-2*s

eqp=solve(f(s)==0,s)
eqp
# Out:
# [s == 0, s == 2]

# %%
x1=eqp[0].rhs()
x1
# Out:
# 0

# %%
x2=eqp[1].rhs()
x2
# Out:
# 2

# %%
diff(f,s)(x1)
# Out:
# -2

# %%
diff(f,s)(x2)
# Out:
# 2

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
deq=diff(x,t)==f(x)
deq
# Out:
# diff(x(t), t) == x(t)^2 - 2*x(t)

# %%
desolve_rk4(deq, x, [0,0.5], step=0.5, end_points= [-5,5], output='list')
# Out:
# [[-5.0, 1.999691078018473],
#  [-4.5, 1.999176396528509],
#  [-4.0, 1.997805063405105],
#  [-3.5, 1.994156341557743],
#  [-3.0, 1.984484162775843],
#  [-2.5, 1.959096237715859],
#  [-2.0, 1.894161295675854],
#  [-1.5, 1.738769486036237],
#  [-1.0, 1.421781241419412],
#  [-0.5, 0.9502219755189003],
#  [0, 0.500000000000000],
#  [0.5, 0.2195310529756966],
#  [1.0, 0.08779173689488134],
#  [1.5, 0.03375154939384906],
#  [2.0, 0.01277697350973469],
#  [2.5, 0.004808449711671268],
#  [3.0, 0.001805581308463883],
#  [3.5, 0.000677432809408831],
#  [4.0, 0.000254085118939742],
#  [4.5, 9.52886451435284e-05],
#  [5.0, 3.57341877871096e-05]]

# %%
desolve_rk4(deq, x, [0,0.5], step=0.1, end_points= [-5,5], output='plot')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#1 b)
reset()
t=var('t')
x=function('x')(t)

# %%
s=var('s')
f=function('f')(s)
f(s)=s*(s-1)*(s-2)

eqp=solve(f(s)==0,s)
eqp
# Out:
# [s == 0, s == 1, s == 2]

# %%
x1=eqp[0].rhs()
x1
# Out:
# 0

# %%
x2=eqp[1].rhs()
x2
# Out:
# 1

# %%
x3=eqp[2].rhs()
x3
# Out:
# 2

# %%
diff(f,s)(x1)
# Out:
# 2

# %%
diff(f,s)(x2)
# Out:
# -1

# %%
diff(f,s)(x3)
# Out:
# 2

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
deq=diff(x,t)==f(x)
deq
# Out:
# diff(x(t), t) == (x(t) - 1)*(x(t) - 2)*x(t)

# %%
desolve_rk4(deq, x, [0,0.5], step=0.5, end_points= [-5,5], output='list')
# Out:
# [[-5.0, 7.76475532971436e-05],
#  [-4.5, 0.000207024419882552],
#  [-4.0, 0.000551811253600373],
#  [-3.5, 0.00146969441005897],
#  [-3.0, 0.003906425603298619],
#  [-2.5, 0.01032745819186345],
#  [-2.0, 0.02692147578793916],
#  [-1.5, 0.06772664109158424],
#  [-1.0, 0.1568557616668755],
#  [-0.5, 0.310583977414987],
#  [0, 0.500000000000000],
#  [0.5, 0.6694576381082618],
#  [1.0, 0.7921575890602431],
#  [1.5, 0.872135878529125],
#  [2.0, 0.9220132032064505],
#  [2.5, 0.9525889870167665],
#  [3.0, 0.9712119931731407],
#  [3.5, 0.982527716100269],
#  [4.0, 0.9893973082819161],
#  [4.5, 0.9935663681238069],
#  [5.0, 0.9960962089348951]]

# %%
desolve_rk4(deq, x, [0,0.5], step=0.1, end_points= [-5,5], output='plot')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
g1=desolve_rk4(deq, x, [0,-1.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g2=desolve_rk4(deq, x, [0,-1], step=0.01, end_points= [-5,5], output='plot',color='black')
g3=desolve_rk4(deq, x, [0,-0.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g4=desolve_rk4(deq, x, [0,0], step=0.01, end_points= [-5,5], output='plot',color='black')
g5=desolve_rk4(deq, x, [0,0.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g6=desolve_rk4(deq, x, [0,1], step=0.01, end_points= [-5,5], output='plot',color='black')
g7=desolve_rk4(deq, x, [0,1.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g=sf+g1+g2+g3+g4+g5+g6+g7
g.show(ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
#1 c)
reset()
t=var('t')
x=function('x')(t)

# %%
s=var('s')
f=function('f')(s)
f(s)=sin(s)

eqp=solve(f(s)==0, s, to_poly_solve='force')
eqp
# Out:
# [s == pi*z1659]

# %%
x1=eqp[0].rhs()
x1
# Out:
# pi*z1659

# %%
diff(f,s)(x1)
# Out:
# cos(pi*z1659)

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
deq=diff(x,t)==f(x)
deq
# Out:
# diff(x(t), t) == sin(x(t))

# %%
desolve_rk4(deq, x, [0,0.5], step=0.5, end_points= [-5,5], output='list')
# Out:
# [[-5.0, 0.003454368099815533],
#  [-4.5, 0.005693026153056634],
#  [-4.0, 0.009382454683324264],
#  [-3.5, 0.01546273554288458],
#  [-3.0, 0.02548278136475221],
#  [-2.5, 0.04199348616809466],
#  [-2.0, 0.06919075821374424],
#  [-1.5, 0.1139534051204141],
#  [-1.0, 0.1874567393334718],
#  [-0.5, 0.3074103972095664],
#  [0, 0.500000000000000],
#  [0.5, 0.7968219262580007],
#  [1.0, 1.213230857969684],
#  [1.5, 1.704886847916107],
#  [2.0, 2.166490645342345],
#  [2.5, 2.519138272183961],
#  [3.0, 2.756092788003508],
#  [3.5, 2.905846057031928],
#  [4.0, 2.998130188736746],
#  [4.5, 3.054449688119642],
#  [5.0, 3.088695760120419]]

# %%
desolve_rk4(deq, x, [0,0.5], step=0.1, end_points= [-5,5], output='plot')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
g1=desolve_rk4(deq, x, [0,-1.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g2=desolve_rk4(deq, x, [0,-1], step=0.01, end_points= [-5,5], output='plot',color='black')
g3=desolve_rk4(deq, x, [0,-0.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g4=desolve_rk4(deq, x, [0,0], step=0.01, end_points= [-5,5], output='plot',color='black')
g5=desolve_rk4(deq, x, [0,0.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g6=desolve_rk4(deq, x, [0,1], step=0.01, end_points= [-5,5], output='plot',color='black')
g7=desolve_rk4(deq, x, [0,1.5], step=0.01, end_points= [-5,5], output='plot',color='blue')
g=sf+g1+g2+g3+g4+g5+g6+g7
g.show(ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
#2 a)
reset()
x,y,t=var('x,y,t')
f1(x,y)=2*x+y
f2(x,y)=x+2*y
desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
# Out:
# [[-1.0, 0.3678797744124984, -0.3678797744124984],
#  [-0.9, 0.4065699912000756, -0.4065699912000756],
#  [-0.8, 0.4493292897344282, -0.4493292897344282],
#  [-0.7000000000000001, 0.496585618671229, -0.496585618671229],
#  [-0.6000000000000001, 0.548811934376315, -0.548811934376315],
#  [-0.5, 0.6065309344233799, -0.6065309344233799],
#  [-0.4, 0.6703202889174906, -0.6703202889174906],
#  [-0.3, 0.7408184220011776, -0.7408184220011776],
#  [-0.2, 0.8187309014062499, -0.8187309014062499],
#  [-0.1, 0.9048375, -0.9048375],
#  [0, 1, -1],
#  [0.1, 1.105170833333333, -1.105170833333333],
#  [0.2, 1.221402570850694, -1.221402570850694],
#  [0.3, 1.349858497062538, -1.349858497062538],
#  [0.4, 1.491824240080686, -1.491824240080686],
#  [0.5, 1.648720638596838, -1.648720638596838],
#  [0.6000000000000001, 1.822117962091933, -1.822117962091933],
#  [0.7000000000000001, 2.013751626596777, -2.013751626596777],
#  [0.8, 2.225539563292315, -2.225539563292315],
#  [0.9, 2.459601413780071, -2.459601413780071],
#  [1.0, 2.718279744135166, -2.718279744135166]]

# %%
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY
# Out:
# [[0.3678797744124984, -0.3678797744124984],
#  [0.4065699912000756, -0.4065699912000756],
#  [0.4493292897344282, -0.4493292897344282],
#  [0.496585618671229, -0.496585618671229],
#  [0.548811934376315, -0.548811934376315],
#  [0.6065309344233799, -0.6065309344233799],
#  [0.6703202889174906, -0.6703202889174906],
#  [0.7408184220011776, -0.7408184220011776],
#  [0.8187309014062499, -0.8187309014062499],
#  [0.9048375, -0.9048375],
#  [1, -1],
#  [1.105170833333333, -1.105170833333333],
#  [1.221402570850694, -1.221402570850694],
#  [1.349858497062538, -1.349858497062538],
#  [1.491824240080686, -1.491824240080686],
#  [1.648720638596838, -1.648720638596838],
#  [1.822117962091933, -1.822117962091933],
#  [2.013751626596777, -2.013751626596777],
#  [2.225539563292315, -2.225539563292315],
#  [2.459601413780071, -2.459601413780071],
#  [2.718279744135166, -2.718279744135166]]

# %%
list_plot(XY,plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2 b)
reset()
x,y,t=var('x,y,t')
f1(x,y)=-3*x+4*y
f2(x,y)=-2*x+3*y
desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY

list_plot(XY,plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2 c)
reset()
x,y,t=var('x,y,t')
f1(x,y)=-x-y
f2(x,y)=x-3*y
desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY

list_plot(XY,plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2 d)
reset()
x,y,t=var('x,y,t')
f1(x,y)=x+4*y
f2(x,y)=x+y
desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY

list_plot(XY,plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2 e)
reset()
x,y,t=var('x,y,t')
f1(x,y)=2*x-y
f2(x,y)=x+2*y
desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY

list_plot(XY,plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#2 f)
reset()
x,y,t=var('x,y,t')
f1(x,y)=-y
f2(x,y)=x
desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY

list_plot(XY,plotjoined=True, color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#3a)
reset()
x,y,t=var('x,y,t')
f1(x,y)=y
f2(x,y)=x*(1-x*x)+y

EquilP=solve([f1(x,y)==0,f2(x,y)==0],x,y)
EquilP
# Out:
# [[x == -1, y == 0], [x == 1, y == 0], [x == 0, y == 0]]

# %%
J=jacobian((f1(x,y),f2(x,y)), (x,y))
J
# Out:
# [         0          1]
# [-3*x^2 + 1          1]

# %%
J(x=-1,y=0)

J(x=-1,y=0).eigenvalues()
# Out:
# [-1/2*sqrt(5) + 1/2, 1/2*sqrt(5) + 1/2]

# %%
J(x=1,y=0)

J(x=1,y=0).eigenvalues()
# Out:
# [-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]

# %%
J(x=0,y=0)

J(x=0,y=0).eigenvalues()
#(-1,0) instabil de tip focus
#(1,0) instabil de tip focus
#(0,0) instabil de tip focus
# Out:
# [-1/2*sqrt(5) + 1/2, 1/2*sqrt(5) + 1/2]

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-3,3], [y,-3,3],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,3], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-0.5,3], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-0.5,-1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,-2], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,-2], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-3,xmax=3,ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#3b)
reset()
x,y,t=var('x,y,t')
f1(x,y)=-2*x+y+2
f2(x,y)=x*y

EquilP=solve([f1(x,y)==0,f2(x,y)==0],x,y)
EquilP
# Out:
# [[x == 1, y == 0], [x == 0, y == -2]]

# %%
J=jacobian((f1(x,y),f2(x,y)), (x,y))
J
# Out:
# [-2  1]
# [ y  x]

# %%
J(x=1,y=0)

J(x=1,y=0).eigenvalues()
# Out:
# [-2, 1]

# %%
J(x=0,y=-2)

J(x=0,y=-2).eigenvalues()
#(1,0) instabil de tip sa
#(0,-2) asimptotic stabil
# Out:
# [-I - 1, I - 1]

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-3,3], [y,-3,3],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,3], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-0.5,3], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-0.5,-1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,-2], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,-2], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-3,xmax=3,ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
#3c)
reset()
x,y,t=var('x,y,t')
f1(x,y)=x*x-y*y
f2(x,y)=x*y-1

EquilP=solve([f1(x,y)==0,f2(x,y)==0],x,y)
EquilP
# Out:
# [[x == -I, y == I], [x == I, y == -I], [x == -1, y == -1], [x == 1, y == 1]]

# %%
J=jacobian((f1(x,y),f2(x,y)), (x,y))
J
# Out:
# [ 2*x -2*y]
# [   y    x]

# %%
J(x=-i,y=i)

J(x=-i,y=i).eigenvalues()
# Out:
# [-1/2*sqrt(7) - 3/2*I, 1/2*sqrt(7) - 3/2*I]

# %%
J(x=i,y=-i)

J(x=i,y=-i).eigenvalues()
# Out:
# [-1/2*sqrt(7) + 3/2*I, 1/2*sqrt(7) + 3/2*I]

# %%
J(x=-1,y=-1)

J(x=-1,y=-1).eigenvalues()
# Out:
# [-1/2*I*sqrt(7) - 3/2, 1/2*I*sqrt(7) - 3/2]

# %%
J(x=1,y=1)

J(x=1,y=1).eigenvalues()

#(-i,i) instabil de tip focus
#(i,-i) instabil de tip focus
#(-1,-1) asimptotic stabil
#(1,1) instabil de tip focus
# Out:
# [-1/2*I*sqrt(7) + 3/2, 1/2*I*sqrt(7) + 3/2]

# %%
n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-3,3], [y,-3,3],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,3], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-0.5,3], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-0.5,-1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-2,-2], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,-2], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-3,xmax=3,ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 9 graphics primitives
